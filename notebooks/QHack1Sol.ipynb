# %%
# Core libraries
import numpy as np
import matplotlib.pyplot as plt

# Qiskit core
from qiskit import QuantumCircuit, transpile
from qiskit.circuit import Parameter, ParameterVector
from qiskit.circuit.library import DiagonalGate, grover_operator, MCMTGate, ZGate
from qiskit.quantum_info import Operator, Pauli, SparsePauliOp, Statevector
from qiskit.visualization import plot_histogram, plot_bloch_multivector, plot_bloch_vector

# Qiskit Aer simulator
from qiskit_aer import AerSimulator, Aer

# IBM runtime (optional, for cloud backends)
from qiskit_ibm_runtime.fake_provider import FakeVigoV2

# Misc
import qiskit.qasm3
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

# %config InlineBackend.figure_format = 'retina'

# %%
import sys
from pathlib import Path

# Add the parent directory to the path so we can import from src
notebook_dir = Path.cwd()
project_root = notebook_dir.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.board import generate_positions
from src.oracle import create_multi_target_oracle

# %%
generate_positions(4)
# Out:
# ['011110', '011101', '100101', '000010']

# %%
#build qiskit circuit
qc = QuantumCircuit(6)
positions = generate_positions(4)
qc.h(range(6))
grover_op = grover_operator(create_multi_target_oracle(positions))
#apply grover operator 3 times
for i in range(3):
  qc.append(grover_op, range(6))
qc.measure_all()
